# %%
#Import Statements
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
census = pd.read_csv (r'cen.csv')

# %%
census
# Out:
#     Country.Area.Name FIPS GENC           Subregion  Region  Year  \
# 0         Afghanistan   AF   AF  South-Central Asia    Asia  2000
# 1         Afghanistan   AF   AF  South-Central Asia    Asia  2020
# 2             Albania   AL   AL     Southern Europe  Europe  2000
# 3             Albania   AL   AL     Southern Europe  Europe  2020
# 4             Algeria   AG   DZ     Northern Africa  Africa  2000
# ..                ...  ...  ...                 ...     ...   ...
# 451             Yemen   YM   YE        Western Asia    Asia  2020
# 452            Zambia   ZA   ZM      Eastern Africa  Africa  2000
# 453            Zambia   ZA   ZM      Eastern Africa  Africa  2020
# 454          Zimbabwe   ZI   ZW      Eastern Africa  Africa  2000
# 455          Zimbabwe   ZI   ZW      Eastern Africa  Africa  2020
#
#      Total.Fertility.Rate  Life.Expectancy.at.Birth..Both.Sexes  \
# 0                  8.0000                                 45.49
# ...

# %%
c20 = census[census['Year']>2019]

# %%
c20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 228 entries, 1 to 455
# Data columns (total 10 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Country.Area.Name                     228 non-null    object
#  1   FIPS                                  228 non-null    object
#  2   GENC                                  227 non-null    object
#  3   Subregion                             228 non-null    object
#  4   Region                                228 non-null    object
#  5   Year                                  228 non-null    int64
#  6   Total.Fertility.Rate                  228 non-null    float64
#  7   Life.Expectancy.at.Birth..Both.Sexes  228 non-null    float64
#  8   Life.Expectancy.at.Birth..Males       228 non-null    float64
#  9   Life.Expectancy.at.Birth..Females     228 non-null    float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 19.6+ KB

# %%
c20.shape
# Out:
# (228, 10)
